# %%
import pickle
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import olympus

# %%
# load results
res = pickle.load(open('result_campaigns.pkl', 'rb'))

all_results = []

for campaign in res:
    run = []
    planner = campaign.planner_kind
    params = campaign.observations.get_params(as_array=True)
    values = campaign.observations.get_values(as_array=True)

    for ix, (p, v) in enumerate(zip(params, values)):
        
        run.append(
            'iter': ix, 
            ''
        )
# Out:
# [['imidazolium' 'Ge' 'F']
#  ['ethylammonium' 'Pb' 'F']
#  ['trimethylammonium' 'Pb' 'Br']
#  ['isopropylammonium' 'Sn' 'I']
#  ['azetidinium' 'Ge' 'Br']
#  ['methylammonium' 'Pb' 'Br']
#  ['azetidinium' 'Sn' 'Cl']
#  ['azetidinium' 'Pb' 'F']
#  ['methylammonium' 'Sn' 'Br']
#  ['acetamidinium' 'Ge' 'F']
#  ['acetamidinium' 'Ge' 'I']
#  ['trimethylammonium' 'Pb' 'Cl']
#  ['guanidinium' 'Ge' 'I']
#  ['tetramethylammonium' 'Sn' 'Cl']
#  ['tetramethylammonium' 'Ge' 'Cl']
#  ['hydroxylammonium' 'Sn' 'Cl']
#  ['hydroxylammonium' 'Pb' 'I']
#  ['propylammonium' 'Ge' 'I']
#  ['hydrazinium' 'Ge' 'Cl']
#  ['ammonium' 'Sn' 'Br']
#  ['ammonium' 'Pb' 'Cl']
#  ['propylammonium' 'Sn' 'F']
#  ['ammonium' 'Pb' 'Br']
#  ['formamidinium' 'Ge' 'Cl']
#  ['dimethylammonium' 'Sn' 'I']
#  ['hydrazinium' 'Pb' 'Br']
#  ['acetamidinium' 'Pb' 'F']
#  ['hydroxylammonium' 'Ge' 'Cl']
#  ['dimethylammonium' 'Sn' 'Cl']
#  ['butylammonium' 'Sn' 'F']
#  ['trimethylammonium' 'Ge' 'F']
#  ['ethylammonium' 'Ge' 'F']
# ...
